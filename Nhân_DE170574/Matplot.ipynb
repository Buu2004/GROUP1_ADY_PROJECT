# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import glob

# %%
def read_name_file(link,format):
    txt_files = glob.glob(os.path.join(link,'*.{0}'.format(format)))
    return txt_files
paths = read_name_file('D:/not sure but it is the Fucking BUGggg!!/DATA FOR ADY','csv')
c = paths[8] 
paths.remove(paths[8])
paths.insert(0,c)
paths
# Out:
# ['D:/not sure but it is the Fucking BUGggg!!/DATA FOR ADY\\Tổng-thiệt-hại.csv',
#  'D:/not sure but it is the Fucking BUGggg!!/DATA FOR ADY\\Chỉ số giá sản xuất công nghiệp  (Năm trước = 100) chia theo Nhóm hàng và Năm.csv',
#  'D:/not sure but it is the Fucking BUGggg!!/DATA FOR ADY\\Chỉ số giá sản xuất dịch vụ (Năm trước = 100) chia theo Chỉ số giá sản xuất dịch vụ và Năm.csv',
#  'D:/not sure but it is the Fucking BUGggg!!/DATA FOR ADY\\Chỉ số giá sản xuất nông, lâm nghiệp và thuỷ sản  (Năm trước = 100) chia theo Ngành và Năm.csv',
#  'D:/not sure but it is the Fucking BUGggg!!/DATA FOR ADY\\Chỉ số giá tiêu dùng các tháng trong năm chia theo Các tháng (tháng trước = 100) và Năm.csv',
#  'D:/not sure but it is the Fucking BUGggg!!/DATA FOR ADY\\Diện tích, dân số và mật độ dân số phân theo địa phương chia theo Địa phương, Năm và Chỉ tiêu.csv',
# ...

# %%
titles = []
for path in paths:
    file = path.split('\\')
    tittle = file[-1].replace('.csv','')
    titles.append(tittle)
titles
# Out:
# ['Tổng-thiệt-hại',
#  'Chỉ số giá sản xuất công nghiệp  (Năm trước = 100) chia theo Nhóm hàng và Năm',
#  'Chỉ số giá sản xuất dịch vụ (Năm trước = 100) chia theo Chỉ số giá sản xuất dịch vụ và Năm',
#  'Chỉ số giá sản xuất nông, lâm nghiệp và thuỷ sản  (Năm trước = 100) chia theo Ngành và Năm',
#  'Chỉ số giá tiêu dùng các tháng trong năm chia theo Các tháng (tháng trước = 100) và Năm',
#  'Diện tích, dân số và mật độ dân số phân theo địa phương chia theo Địa phương, Năm và Chỉ tiêu',
#  'Lực lượng lao động từ 15 tuổi trở lên phân theo địa phương() chia theo Địa phương và Năm',
#  'Một số chỉ tiêu chủ yếu về tài khoản quốc gia chia theo Chỉ tiêu và Năm',
#  'Tổng sản phẩm trong nước theo giá thực tế phân theo khu vực kinh tế chia theo Năm, Chỉ tiêu và Khu vực kinh tế',
#  'Đầu tư trực tiếp của nước ngoài được cấp giấy phép thời kỳ 1988 - 2021 chia theo Năm và Phân tổ']

# %%
def readcsv(path):
    order = pd.read_csv(path)
    return order

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i,y[i],y[i])

# %%
# data_y = []
# for i in paths[:7]:
#     df = readcsv(i)
#     values = [df.columns.tolist()[1:],df.values.tolist()]
#     data_y.append(values)
# for i in data_y:
#     print(i)

# %%
data_y = []
for i in paths[:8]:
    df = readcsv(i)
    values = [df.columns.tolist()[1:],df.values.tolist()]
    data_y.append(values)
for i in paths[8:]:    
    df = readcsv(i)
    # print(df)
    data_np = np.array(df.values.tolist())
    a = pd.DataFrame(np.transpose(data_np))
    # print(a)
    transpose = a.values.tolist()[1:]
    # print(transpose)
    column =  df.columns.tolist()[1:]
    # print(column)
    for i in range(len(transpose)):
        transpose[i].insert(0,column[i])
    transpose = [transpose]
    # print(transpose)
    transpose.insert(0,a.values.tolist()[:1][0])
    # print(transpose)
    dumb = []
    for i in transpose[0]:
        dumb.append(str(int(i)))
    transpose[0] = list(dumb)
    data_y.append(transpose)



for i in data_y:
    print(i)
# Out:
# [['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], [['Tổng thiệt hại(tỷ đồng)', 16062, 13507, 16000, 27853, 2828, 8114, 39726, 60000, 20000, 6863, 39962, 5200, 19500]]]
# [['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], [['CHỈ SỐ CHUNG', 112.63, 118.43, 103.43, 105.25, 103.26, 99.42, 99.39, 102.82, 103.09, 101.25, 99.4, 102.91, 104.24]]]
# [['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], [['CHỈ SỐ CHUNG', 103.53, 103.05, 102.98, 101.28, 102.38, 103.63, 103.0, 103.06, 99.27, 100.95, 103.73]]]
# [['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], [['Ngành', 114.4, 131.6, 97.87, 100.57, 104.62, 99.72, 101.71, 99.92, 101.98, 101.31, 108.79, 102.12, 103.89]]]
# ...

# %%
o = 0
for i in data_y:
    for j in i[1]:
        x = np.array(i[0])
        y = np.array(j[1:])
        print(x)
        print(y)
        plt.title(titles[o])
        plt.xlabel('Year')
        plt.ylabel('chỉ số')
        # addlabels(x,y)
        plt.plot(x,y, linestyle = 'dashed',marker = 'o', label = j[0])
        plt.rcParams['figure.figsize'] = [11, 13]
        plt.legend()
    plt.savefig('D:/not sure but it is the Fucking BUGggg!!/DATA FOR ADY/Data_png/%s.png'%titles[o])
    plt.show()
    o += 1
# Out:
# ['2010' '2011' '2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019'
#  '2020' '2021' '2022']
# [16062 13507 16000 27853  2828  8114 39726 60000 20000  6863 39962  5200
#  19500]
# ['2010' '2011' '2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019'
#  '2020' '2021' '2022']
# [112.63 118.43 103.43 105.25 103.26  99.42  99.39 102.82 103.09 101.25
#   99.4  102.91 104.24]
# ['2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019' '2020' '2021'
#  '2022']
# [103.53 103.05 102.98 101.28 102.38 103.63 103.   103.06  99.27 100.95
#  103.73]
# ['2010' '2011' '2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019'
#  '2020' '2021' '2022']
# [114.4  131.6   97.87 100.57 104.62  99.72 101.71  99.92 101.98 101.31
#  108.79 102.12 103.89]
# ['2010' '2011' '2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019'
#  '2020' '2021' '2022']
# [109.19 118.58 109.21 106.6  104.09 100.63 102.66 103.53 103.54 102.79
#  103.23 101.84 103.15]
# ...
